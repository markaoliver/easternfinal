# %% [markdown]
# # Proof of Concept
#
# This document is a proof of concept to confirm whether Binder will work as a way of putting the model in production.

# %%
# standard imports
import pandas as pd
import numpy as np

# Do not change this option; This allows the CodeGrade auto grading to function correctly
pd.set_option('display.max_columns', 20)
# Out:
# C:\Users\MarkA\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pd.DataFrame({'A': [1, 2], 'B': ['A', 'B']})
# Out:
#    A  B
# 0  1  A
# 1  2  B
